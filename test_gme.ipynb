# %%
import numpy as np
from phc import PhotCryst, Lattice

# %load_ext autoreload
# %autoreload 2

from gme import GuidedModeExp
from utils import plot_reciprocal
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Initialize a lattice
lattice = Lattice('square')
# Initialize a PhC (by default with eps = 1 in upper and lower cladding, we set upper one to 5)
phc = PhotCryst(lattice)
# Add a layer to the PhC with thickness 1 and background permittivity 10
phc.add_layer(d=1, eps_b=12)
# Add a shape to this layer 
phc.add_shape('circle', {'x': 0, 'y': 0.4, 'r': 0.3, 'eps': 1}, layer_ind=0)
phc.add_shape('circle', {'x': 0.2, 'y': 0, 'r': 0.2, 'eps': 1}, layer_ind=0)
# Plot an overview picture
phc.plot_overview()

# %%
gme = GuidedModeExp(phc, gmax=5)

# %%
gme.plot_overview_ft()

# %%
# Initialize a lattice
lattice = Lattice('hexagonal')
# Initialize a PhC (by default with eps = 1 in upper and lower cladding, we set upper one to 5)
phc = PhotCryst(lattice)
# Add a layer to the PhC with thickness 1 and background permittivity 10
phc.add_layer(d=1, eps_b=12)
# Add shapes to this layer 
phc.add_shape('circle', {'x': 0, 'y': 0.3, 'r': 0.2, 'eps': 1}, layer_ind=0)
phc.add_shape('circle', {'x': 0.2, 'y': 0, 'r': 0.1, 'eps': 5}, layer_ind=0)
# Add another layer and a shape
phc.add_layer(d=1, eps_b=12)
phc.layers[-1].add_shape('circle', {'x': 0, 'y': 0.1, 'r': 0.2, 'eps': 1})
# Plot an overview picture
phc.plot_overview()

# %%
gme = GuidedModeExp(phc, gmax=5)
gme.plot_overview_ft()

# %%
# Initialize a lattice
lattice = Lattice([1, 0], [1, 2])
# Initialize a PhC (by default with eps = 1 in upper and lower cladding, we set upper one to 5)
phc = PhotCryst(lattice)
# Add a layer to the PhC with thickness 1 and background permittivity 10
phc.add_layer(d=1, eps_b=12)
# Add a shape to this layer 
# phc.add_shape('circle', {'x': 0, 'y': 0.2, 'r': 0.4, 'eps': 1}, layer_ind=0)
phc.add_shape('circle', {'x': 0.2, 'y': 0, 'r': 0.2, 'eps': 1}, layer_ind=0)
# Plot an overview picture
phc.plot_overview()

# %%
gme = GuidedModeExp(phc, gmax=5)
gme.plot_overview_ft()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-115-0bece80bb550> in <module>()
# ----> 1 gme = GuidedModeExp(phc, gmax=5)
#       2 gme.plot_overview_ft()
#
# ~/Drive/Postdoc/Python/pyGME/gme.py in __init__(self, phc, kpoints, gmax, gmode_inds, numeig, om_target)
#      23                 # Initialize the reciprocal lattice vectors
#      24                 self._init_reciprocal()
# ---> 25                 self._init_ft()
#      26
#      27         def _init_reciprocal(self):
#
# ~/Drive/Postdoc/Python/pyGME/gme.py in _init_ft(self)
#      58                 for ind1 in range(n1max):
#      59                         G2[:, ind1*n1max:(ind1+1)*n2max] = self.gvec[:, [ind1*n2max]] - \
# ---> 60                                                         self.gvec[:, range(n2max)]
#      61
#      62                 # print(self.gvec,'\n', G1/2/np.pi,'\n', G2/2/np.pi,'\n')
#
# ValueError: could not broadcast input array from shape (2,21) into shape (2,33)

# %%
print(lattice.b1, lattice.b2)
# Out:
# [ 6.28318531 -3.14159265] [0.         3.14159265]
