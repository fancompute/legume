# %%
import numpy as np
from utils import init_lattice
from phc import PhotCryst

# %load_ext autoreload
# %autoreload 2

# %%
# Initialize a lattice (by default it's square with lattice period 1)
lattice = init_lattice()
print(lattice)
# Out:
# {'a1': array([1, 0]), 'a2': array([0, 1]), 'b1': array([6.28318531, 0.        ]), 'b2': array([0.        , 6.28318531]), 'ec_area': 1.0, 'bz_area': 39.47841760435743}

# %%
# Initialize a PhC (by default with eps = 1 in upper and lower cladding, we set upper one to 5)
phc = PhotCryst(lattice, eps_u = 5)

# %%
# Add a layer to the PhC with thickness 1 and background permittivity 10
phc.add_layer(d=1, eps_b=10)

# %%
# Add a shape to this layer 
phc.add_shape('circle', {'x': 0, 'y': 0, 'r': 0.2, 'eps': 1}, layer_ind=0)

# %%
# Add another layer and another shape
phc.add_layer(d=0.5, eps_b=6)
phc.add_shape('circle', {'x': 0.3, 'y': 0, 'r': 0.3, 'eps': 12}, layer_ind=1)

# %%
# Print an xz cross section of the permittivity
phc.plot_cross('xz')

# %%
# Plot an overview picture
phc.plot_overview()

# %%
# Add let's try one more layer for the fun of it
phc.add_layer(d=0.7, eps_b=2)
# Shapes can also be added to the layer directily:
phc.layers[-1].add_shape('circle', {'x': 0.1, 'y': 0, 'r': 0.1, 'eps': 8})
phc.plot_overview()

# %%
# We can also do polygonal shapes
phc = PhotCryst(lattice)
phc.add_layer(d=1, eps_b=10)
phc.layers[-1].add_shape('square', {'x_cent': 0.2, 'y_cent': 0.5, 'a': 0.3, 'eps': 2})
phc.plot_overview()

# %%
# We can also add an arbitrary polygon 
phc.add_layer(d=0.4, eps_b=8)
phc.layers[-1].add_shape('poly', {'x_edges': [-0.1, 0.5, 0.2], 'y_edges': [0, 0, 0.5], 'eps': 4})
phc.plot_overview()
